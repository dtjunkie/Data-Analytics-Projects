# %%
# Importing Pandas
import pandas as pd

# %%
# Reads the json file embedded from a news website
voters_profile = pd.read_json("https://data.gmanetwork.com/gno/microsites/eleksyon2022/voters_profile/provinces.gz")

# Transposes the indexes and columns
voters_profile = voters_profile.T

# Resets the index of the dataframe
voters_profile = voters_profile.reset_index()

# Rename the first column from 'index' to 'province'
voters_profile = voters_profile.rename(columns = {'index': 'province'})

# Returns the dataframe
voters_profile
# Out:
#                province  total_both_sex_voters  total_female_voters  \
# 0                  ABRA                 182696                88270
# 1      AGUSAN_DEL_NORTE                 502116               249364
# 2        AGUSAN_DEL_SUR                 442628               216091
# 3                 AKLAN                 409938               204555
# 4                 ALBAY                 890148               457229
# ..                  ...                    ...                  ...
# 77            TAWI-TAWI                 232845               112130
# 78             ZAMBALES                 540309               281549
# 79  ZAMBOANGA_DEL_NORTE                 738543               362372
# 80    ZAMBOANGA_DEL_SUR                1138325               577360
# 81    ZAMBOANGA_SIBUGAY                 422062               206400
#
#     total_male_voters  total_single  total_married  total_widow  \
# 0               94426        100484          78448         3590
# ...

# %%
# Replaces the underscore line in the province name with white space

for i in range(len(voters_profile['province'])):
    white_space = voters_profile['province'][i].replace("_"," ")
    voters_profile['province'][i] = white_space
    
voters_profile['province']
# Out:
# C:\Users\Asus\AppData\Local\Temp/ipykernel_12888/3166518906.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   voters_profile['province'][i] = white_space
# 0                    ABRA
# 1        AGUSAN DEL NORTE
# 2          AGUSAN DEL SUR
# 3                   AKLAN
# 4                   ALBAY
#              ...
# 77              TAWI-TAWI
# 78               ZAMBALES
# 79    ZAMBOANGA DEL NORTE
# 80      ZAMBOANGA DEL SUR
# 81      ZAMBOANGA SIBUGAY
# Name: province, Length: 82, dtype: object

# %%
voters_profile
# Out:
#                province  total_both_sex_voters  total_female_voters  \
# 0                  ABRA                 182696                88270
# 1      AGUSAN DEL NORTE                 502116               249364
# 2        AGUSAN DEL SUR                 442628               216091
# 3                 AKLAN                 409938               204555
# 4                 ALBAY                 890148               457229
# ..                  ...                    ...                  ...
# 77            TAWI-TAWI                 232845               112130
# 78             ZAMBALES                 540309               281549
# 79  ZAMBOANGA DEL NORTE                 738543               362372
# 80    ZAMBOANGA DEL SUR                1138325               577360
# 81    ZAMBOANGA SIBUGAY                 422062               206400
#
#     total_male_voters  total_single  total_married  total_widow  \
# 0               94426        100484          78448         3590
# ...
